# %%
import pandas as pd

# %%
df = pd.read_csv('oer_records.csv')

# %%
df.head()
# Out:
#                           doi  \
# 0  10.1038/s41598-026-52116-3
# 1          10.1038/ncomms5345
# 2          10.1038/ncomms9249
# 3  10.1038/s41467-022-28260-5
# 4  10.1038/s41467-025-65626-x
#
#                                           source_pdf  \
# 0  Sustainable_synthesis_of_Ni-doped_Co3O4graphen...
# 1  Electrochemical_tuning_of_layered_lithium_tran...
# 2  Covalency-reinforced_oxygen_evolution_reaction...
# 3  Electrode_reconstruction_strategy_for_oxygen_e...
# 4  Atomic-scale_insights_into_surface_reconstruct...
#
#                                                title  \
# 0  © The Author(s) 2026. Open Access This article...
# 1  1 Department of Material Science and Engineeri...
# 2                                               OPEN
# 3                                               OPEN
# 4  Atomic-scale insights into surface reconstruct...
#
#                                             abstract                material  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   doi               401 non-null    str
#  1   source_pdf        402 non-null    str
#  2   title             402 non-null    str
#  3   abstract          402 non-null    str
#  4   material          370 non-null    str
#  5   substrate         363 non-null    str
#  6   electrolyte       344 non-null    str
#  7   overpotential_mV  253 non-null    float64
#  8   current_density   253 non-null    float64
#  9   confidence        402 non-null    float64
#  10  extraction_note   402 non-null    str
#  11  anchor_found      402 non-null    bool
#  12  anchor_sentence   253 non-null    str
# dtypes: bool(1), float64(3), str(9)
# memory usage: 38.2 KB

# %%
df.shape
# Out:
# (402, 13)

# %%
df = df[df['anchor_found']]

# %%
df.shape
# Out:
# (253, 13)

# %%
df = df.drop(['title', 'anchor_sentence', 'anchor_found', 'extraction_note'], axis=1)

# %%
df.head()
# Out:
#                            doi  \
# 3   10.1038/s41467-022-28260-5
# 4   10.1038/s41467-025-65626-x
# 8   10.1038/s41467-025-55857-3
# 13  10.1038/s41467-024-46801-y
# 16  10.1038/s41467-021-26025-0
#
#                                            source_pdf  \
# 3   Electrode_reconstruction_strategy_for_oxygen_e...
# 4   Atomic-scale_insights_into_surface_reconstruct...
# 8   Operando_monitoring_of_the_functional_role_of_...
# 13  The_formation_of_unsaturated_IrOxin_SrIrO3by_c...
# 16  Restructuring_highly_electron-deficient_metal-...
#
#                                              abstract      material  \
# 3   Computational calculations and experimental st...       CF-FeSO
# 4   Optimizing the activity and longevity of oxyge...       CoCr2O4
# 8   The complexity of the intrinsic oxygen evoluti...  CoII/FeIIIO6
# 13  Electrocatalytic water splitting is a promisin...         SI6C1
# 16  The poor catalyst stability in acidic oxidatio...          MoO3
#
# ...

# %%
df.to_csv('oer_limpo_2.csv', index=False)

# %%
has_duplicates = df['doi'].duplicated().any()
print(has_duplicates)
# Out:
# False
